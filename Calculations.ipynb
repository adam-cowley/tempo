# %%
# %pip install neo4j pandas

# %% [markdown]
# The data has been imported into Neo4j, a Graph Database.  Graph Databases allow you to look at the data in terms of Nodes and Relationships rather than rows and columns.
#
# ![Data Model](images/model.svg)
#
# [Cypher](https://neo4j.com/docs/cypher-manual/current/introduction/cypher_overview/), Neo4j's query language allows you to find patterns in the chain of events.   For example, a specific pattern:
#
# ```cypher
# MATCH sequence =
# (:Carry)-[:NEXT_EVENT]->(:Pass)-[:NEXT_EVENT]->(:BallReceipt)-[:NEXT_EVENT]->(:Carry)-[:NEXT_EVENT]->(:Pass)-[:NEXT_EVENT]->(:BallReceipt)
# ```
#
# Or a non-specific pattern of events that start and end with a particular event type.
#
# ```cypher
# MATCH sequence = (:BallReceipt)-[:NEXT_EVENT*1..3]->(:BallReceipt)
# ```
#
# ![Pass Sequence](images/pass-sequence.svg)
#
# In the case of the StatsBomb data, there may be many variable event types between a Ball Receipt and a Pass, for example: Ball Receipt, Carry, Dribble, Pass or as simple as Ball Receipt, Pass.
#
# The events are linked to a Match node, which is linked to a Stadium node.  The Stadium node holds the pitch dimensions and a ratio (width: `120/actual width`, length: `80/actual length`) which is used to calculate the actual distance.
#
# _The data has been imported in a separate notebook._
#
#
# ## Connecting to Neo4j
#
# The following code creates an instance of the [Neo4j Python Driver](https://neo4j.com/docs/python-manual/current/), through which we can interact with the Neo4j database.

# %%
# Connect to Neo4j
from neo4j import GraphDatabase, Result

driver = GraphDatabase.driver(
    "neo4j://localhost:7687", 
    auth=("neo4j", "neoneoneo")
)

driver.verify_connectivity()

# %% [markdown]
# ## Pitch Dimensions
#
# The following code takes the pitch dimension information provided and assigns a `dimensions` property to the stadium node and calculates a ratio.  The two properties are `point` properties, which contain an `x` and `y`.  This will be used to adjust the locations in the Statsbomb data.

# %%
# Load Stadium Dimensions
import pandas as pd

pitch_df = pd.read_csv('import/pl-pitch-dimensions.csv')
        
driver.execute_query("""
    UNWIND $rows AS row
    MATCH (s:Stadium)
    WHERE trim(s.name) = trim(row.`Stadium `)
    SET s.dimensions = point({ x: row.`Pitch Length (m)`, y: row.`Pitch Width (m)`}),
    s.ratio = point({ x: s.dimensions.x / 120, y: s.dimensions.y / 80})
    RETURN count(*),  collect(s.name)
""", rows = [dict(row) for _, row in pitch_df.iterrows()])

# %% [markdown]
# ## Event Types
#
# The following list contains all values for an event `type` in the Statsbomb dataset.

# %%
event_types_df = driver.execute_query(
    "MATCH (e:Event) RETURN e.type AS type, count(e) AS count ORDER BY type ASC",
    database_="neo4j",
    result_transformer_=Result.to_df
)
event_types_df
# Out:
#                  type   count
# 0               50/50    1443
# 1           6 Seconds       2
# 2       Backpass Pick       2
# 3       Bad Behaviour     336
# 4       Ball Receipt*  350011
# 5       Ball Recovery   35810
# 6               Block   15153
# 7               Carry  286254
# 8           Clearance   16258
# 9      Dangerous Play      58
# 10       Dispossessed    8555
# 11               Dive      25
# 12            Dribble   10404
# 13      Dribbled Past    6011
# 14               Duel   25991
# 15              Error     194
# 16     Foul Committed    9333
# 17           Foul Out      17
# 18           Foul Won    9388
# 19        Goal Keeper   11697
# 20           Half End    1520
# 21         Half Start    1520
# 22           Handball     318
# 23    Injury Stoppage    2178
# 24       Interception    8490
# 25         Miscontrol    9519
# 26            Offside     135
# 27   Own Goal Against      45
# 28       Own Goal For      45
# 29               Pass  369256
# 30         Player Off     560
# 31          Player On     558
# 32           Pressure  118319
# 33  Referee Ball-Drop     872
# 34             Shield     524
# 35               Shot    9658
# 36        Starting XI     760
# 37       Substitution    2985
# 38     Tactical Shift    1193

# %% [markdown]
# This list has been combined with event outcomes to create a set of node labels that can be used to quickly identify events - eg. unsuccessful passes or shots conceded by the goalkeeper.

# %%
event_labels_df = driver.execute_query(
    "MATCH (e:Event) UNWIND labels(e) AS label RETURN label, count(distinct e) AS count ORDER BY label ASC",
    database_="neo4j",
    result_transformer_=Result.to_df
)
event_labels_df
# Out:
#                             label    count
# 0                    BadBehaviour      336
# 1                     BallReceipt   350011
# 2                    BallRecovery    35810
# 3                           Block    15153
# 4                           Carry   286254
# 5                       Clearance    16258
# 6                    Dispossessed     8555
# 7                         Dribble    10404
# 8                    DribbledPast     6011
# 9                            Duel    25991
# 10                 DuelAerialLost    13073
# 11                       DuelLost     5148
# 12                 DuelLostInPlay     2807
# 13                    DuelLostOut     2341
# 14              DuelSuccessInPlay     4372
# 15                 DuelSuccessOut      502
# 16                     DuelTackle    12918
# 17                        DuelWon     2896
# 18                          Error      194
# 19                          Event  1315397
# 20                     FiftyFifty     1443
# 21                 FiftyfiftyLost      730
# 22  FiftyfiftySuccessToOpposition      179
# 23        FiftyfiftySuccessToTeam      276
# 24                  FiftyfiftyWon      258
# 25                  FoulCommitted     9755
# 26                        FoulWon     9388
# 27                     Goalkeeper    11697
# 28            GoalkeeperCollected      664
# 29         GoalkeeperGoalConceded      965
# 30        GoalkeeperKeeperSweeper      861
# 31      GoalkeeperPenaltyConceded       74
# 32         GoalkeeperPenaltySaved       17
# 33                GoalkeeperPunch      468
# 34                 GoalkeeperSave       16
# 35            GoalkeeperShotFaced     6393
# 36            GoalkeeperShotSaved     2145
# 37   GoalkeeperShotSavedOffTarget       29
# 38      GoalkeeperShotSavedToPost       35
# 39              GoalkeeperSmother       30
# 40                        HalfEnd     1520
# 41                      HalfStart     1520
# 42                 InjuryStoppage     2178
# 43          InjuryStoppageInChain      340
# 44       InjuryStoppageOutOfChain     1838
# 45                   Interception     8490
# 46               InterceptionLost     3366
# 47                     Miscontrol     9519
# 48                        Offside      135
# 49                  OutOfSequence   133574
# 50                 OwnGoalAgainst       45
# 51                     OwnGoalFor       45
# 52                           Pass   369256
# 53                      PlayerOff      560
# 54                       PlayerOn      558
# 55                       Pressure   118319
# 56                       Red Card        5
# 57                RefereeBallDrop      872
# 58                  Second Yellow        2
# 59                         Shield      524
# 60                           Shot     9658
# 61                   ShotBackheel       42
# 62                    ShotBlocked     2860
# 63                     ShotCorner        2
# 64              ShotDiving Header       38
# 65                  ShotFree Kick      292
# 66                       ShotGoal     1039
# 67                ShotHalf Volley     1385
# 68                       ShotHead     1772
# 69                  ShotLeft Foot     3150
# 70                        ShotLob       91
# 71                     ShotNormal     7372
# 72                      ShotOff T     2696
# 73                  ShotOpen Play     9265
# 74                      ShotOther       39
# 75              ShotOverhead Kick       44
# 76                    ShotPenalty       99
# 77                       ShotPost      201
# 78                 ShotRight Foot     4697
# 79                      ShotSaved     2162
# 80           ShotSaved Off Target       29
# 81              ShotSaved to Post       35
# 82                     ShotVolley      686
# 83                    ShotWayward      636
# 84                     StartingXi      760
# 85                   Substitution     2985
# 86          SuccessfulBallReceipt   295920
# 87                 SuccessfulPass   296017
# 88                  TacticalShift     1193
# 89                  UnderPressure   262101
# 90        UnsuccessfulBallReceipt    54091
# 91               UnsuccessfulPass    73239
# 92                    Yellow Card      329

# %% [markdown]
# ### Events that end a possession

# %%
driver.execute_query(
    "MATCH (:Possession)-[:LAST_EVENT]->(e:Event) RETURN e.type AS type, count(*) AS count",
    database_="neo4j",
    result_transformer_=Result.to_df
)
# Out:
#                  type  count
# 0          Half Start    613
# 1                Duel   3950
# 2         Goal Keeper   6075
# 3               Block   4506
# 4       Ball Receipt*  15748
# 5          Miscontrol   3455
# 6                Pass   4352
# 7            Pressure   2401
# 8           Clearance   4127
# 9       Ball Recovery    606
# 10           Foul Won   6943
# 11       Dispossessed   2081
# 12    Injury Stoppage    679
# 13       Substitution   1448
# 14             Shield    282
# 15              50/50    188
# 16          Player On    127
# 17            Dribble   1166
# 18           Handball    254
# 19           Half End    377
# 20         Player Off    492
# 21     Tactical Shift    734
# 22       Interception   1876
# 23  Referee Ball-Drop    631
# 24               Shot    733
# 25              Carry   1974
# 26      Bad Behaviour    243
# 27           Foul Out     17
# 28               Dive     21
# 29     Foul Committed      3
# 30            Offside    103
# 31   Own Goal Against     18
# 32       Own Goal For     18
# 33              Error      8
# 34      Backpass Pick      2

# %%
next_df = driver.execute_query(
    """
        MATCH (p:Possession) 
        WHERE exists { (p)<-[:POSSESSION]-(:BallReceipt)-[:NEXT_BALL_RECEIPT]->() }
        MATCH (p)-[:LAST_EVENT]->(e:Event), 
            (e)-[:TEAM]->(t),
            (p)-[:NEXT_POSSESSION]->()-[:FIRST_EVENT]->(n)-[:TEAM]->(nt)
        RETURN e.type AS type, e.outcome AS outcome, 
            n.type AS next, t = nt AS same_team,
            count(*) AS count
        ORDER BY type, outcome, next
    """,
    database_="neo4j",
    result_transformer_=Result.to_df
)

next_df.to_csv("exports/next_event.csv")

next_df
# Out:
#                  type                outcome               next  same_team  \
# 0               50/50                   Lost              50/50      False
# 1               50/50                   Lost      Ball Recovery      False
# 2               50/50                   Lost      Ball Recovery       True
# 3               50/50                   Lost               Pass       True
# 4               50/50  Success To Opposition      Ball Recovery      False
# 5               50/50  Success To Opposition      Ball Recovery       True
# 6               50/50  Success To Opposition               Pass      False
# 7               50/50        Success To Team      Ball Recovery       True
# 8               50/50        Success To Team               Pass      False
# 9               50/50        Success To Team               Pass       True
# 10      Backpass Pick                   None               Pass      False
# 11      Bad Behaviour                   None               Pass       True
# 12      Bad Behaviour                   None               Pass      False
# 13      Bad Behaviour                   None  Referee Ball-Drop      False
# 14      Bad Behaviour                   None  Referee Ball-Drop       True
# 15      Bad Behaviour                   None               Shot      False
# 16      Bad Behaviour                   None               Shot       True
# 17      Ball Receipt*             Incomplete      Ball Recovery      False
# 18      Ball Receipt*             Incomplete        Goal Keeper      False
# 19      Ball Receipt*             Incomplete       Interception      False
# 20      Ball Receipt*             Incomplete               Pass      False
# 21      Ball Receipt*             Incomplete               Pass       True
# 22      Ball Receipt*             Incomplete  Referee Ball-Drop      False
# 23      Ball Receipt*             Incomplete  Referee Ball-Drop       True
# 24      Ball Receipt*             Incomplete        Starting XI       True
# 25      Ball Receipt*                   None      Ball Recovery      False
# 26      Ball Receipt*                   None               Pass       True
# 27      Ball Receipt*                   None  Referee Ball-Drop      False
# 28      Ball Recovery                   None      Ball Recovery      False
# 29      Ball Recovery                   None      Ball Recovery       True
# 30      Ball Recovery                   None        Goal Keeper       True
# 31      Ball Recovery                   None        Goal Keeper      False
# 32      Ball Recovery                   None               Pass      False
# 33      Ball Recovery                   None               Pass       True
# 34              Block                   None      Ball Recovery       True
# 35              Block                   None      Ball Recovery      False
# 36              Block                   None        Goal Keeper       True
# 37              Block                   None        Goal Keeper      False
# 38              Block                   None       Interception       True
# 39              Block                   None               Pass      False
# 40              Block                   None               Pass       True
# 41              Block                   None  Referee Ball-Drop      False
# 42              Block                   None               Shot      False
# 43              Carry                   None      Ball Recovery       True
# 44              Carry                   None      Ball Recovery      False
# 45              Carry                   None        Goal Keeper      False
# 46              Carry                   None               Pass       True
# 47              Carry                   None               Pass      False
# 48              Carry                   None  Referee Ball-Drop      False
# 49          Clearance                   None      Ball Recovery       True
# 50          Clearance                   None      Ball Recovery      False
# 51          Clearance                   None        Goal Keeper       True
# 52          Clearance                   None        Goal Keeper      False
# 53          Clearance                   None               Pass      False
# 54          Clearance                   None               Pass       True
# 55       Dispossessed                   None               Duel      False
# 56       Dispossessed                   None        Goal Keeper      False
# 57               Dive                   None               Pass      False
# 58            Dribble             Incomplete      Ball Recovery      False
# 59            Dribble             Incomplete               Duel      False
# 60            Dribble             Incomplete        Goal Keeper      False
# 61            Dribble             Incomplete               Pass      False
# 62            Dribble             Incomplete               Pass       True
# 63               Duel                   None      Ball Recovery       True
# 64               Duel                   None      Ball Recovery      False
# 65               Duel                   None        Goal Keeper       True
# 66               Duel                   None               Pass      False
# 67               Duel                   None               Pass       True
# 68              Error                   None      Ball Recovery      False
# 69              Error                   None               Pass      False
# 70     Foul Committed                   None               Pass      False
# 71           Foul Out                   None               Pass      False
# 72           Foul Won                   None      Ball Recovery       True
# 73           Foul Won                   None        Goal Keeper       True
# 74           Foul Won                   None               Pass       True
# 75           Foul Won                   None               Pass      False
# 76           Foul Won                   None               Shot       True
# 77        Goal Keeper                  Clear      Ball Recovery       True
# 78        Goal Keeper                  Clear      Ball Recovery      False
# 79        Goal Keeper                  Clear               Pass      False
# 80        Goal Keeper                  Clear               Pass       True
# 81        Goal Keeper                   Fail      Ball Recovery       True
# 82        Goal Keeper         In Play Danger      Ball Recovery       True
# 83        Goal Keeper         In Play Danger      Ball Recovery      False
# 84        Goal Keeper         In Play Danger               Pass       True
# 85        Goal Keeper           In Play Safe      Ball Recovery       True
# 86        Goal Keeper           In Play Safe      Ball Recovery      False
# 87        Goal Keeper           In Play Safe               Pass       True
# 88        Goal Keeper           In Play Safe               Pass      False
# 89        Goal Keeper               No Touch               Pass       True
# 90        Goal Keeper            Punched out               Pass      False
# 91        Goal Keeper            Saved Twice               Pass       True
# 92        Goal Keeper                Success               Pass       True
# 93        Goal Keeper        Success In Play      Ball Recovery       True
# 94        Goal Keeper            Success Out               Pass       True
# 95        Goal Keeper             Touched In               Pass       True
# 96        Goal Keeper            Touched Out               Pass      False
# 97        Goal Keeper            Touched Out               Pass       True
# 98        Goal Keeper                   None      Ball Recovery       True
# 99        Goal Keeper                   None      Ball Recovery      False
# 100       Goal Keeper                   None        Goal Keeper       True
# 101       Goal Keeper                   None               Pass      False
# 102       Goal Keeper                   None               Pass       True
# 103          Half End                   None        Starting XI       True
# 104          Half End                   None        Starting XI      False
# 105        Half Start                   None               Pass       True
# 106        Half Start                   None               Pass      False
# 107          Handball                   None      Ball Recovery      False
# 108          Handball                   None               Pass      False
# 109          Handball                   None               Shot      False
# 110   Injury Stoppage                   None               Pass       True
# 111   Injury Stoppage                   None               Pass      False
# 112   Injury Stoppage                   None  Referee Ball-Drop       True
# 113   Injury Stoppage                   None  Referee Ball-Drop      False
# 114   Injury Stoppage                   None               Shot       True
# 115   Injury Stoppage                   None               Shot      False
# 116      Interception           Lost In Play      Ball Recovery      False
# 117      Interception           Lost In Play      Ball Recovery       True
# 118      Interception           Lost In Play               Pass      False
# 119      Interception           Lost In Play               Pass       True
# 120      Interception               Lost Out               Pass      False
# 121      Interception               Lost Out               Pass       True
# 122      Interception        Success In Play      Ball Recovery       True
# 123      Interception        Success In Play        Goal Keeper       True
# 124      Interception        Success In Play               Pass       True
# 125      Interception            Success Out               Pass       True
# 126        Miscontrol                   None      Ball Recovery      False
# 127        Miscontrol                   None        Goal Keeper      False
# 128        Miscontrol                   None       Interception      False
# 129        Miscontrol                   None               Pass      False
# 130        Miscontrol                   None               Pass       True
# 131        Miscontrol                   None  Referee Ball-Drop       True
# 132           Offside                   None               Pass      False
# 133  Own Goal Against                   None               Pass       True
# 134      Own Goal For                   None               Pass      False
# 135              Pass             Incomplete      Ball Recovery      False
# 136              Pass             Incomplete        Goal Keeper      False
# 137              Pass             Incomplete       Interception      False
# 138              Pass             Incomplete               Pass      False
# 139              Pass             Incomplete  Referee Ball-Drop       True
# 140              Pass       Injury Clearance               Pass      False
# 141              Pass                    Out               Pass      False
# 142              Pass                    Out               Pass       True
# 143              Pass                Unknown      Ball Recovery      False
# 144              Pass                Unknown       Interception      False
# 145              Pass                Unknown  Referee Ball-Drop      False
# 146        Player Off                   None               Pass       True
# 147        Player Off                   None               Pass      False
# 148        Player Off                   None  Referee Ball-Drop      False
# 149        Player Off                   None  Referee Ball-Drop       True
# 150        Player Off                   None               Shot      False
# 151        Player Off                   None               Shot       True
# 152         Player On                   None      Ball Recovery       True
# 153         Player On                   None               Pass       True
# 154         Player On                   None               Pass      False
# 155         Player On                   None  Referee Ball-Drop      False
# 156         Player On                   None               Shot      False
# 157          Pressure                   None      Ball Recovery      False
# 158          Pressure                   None      Ball Recovery       True
# 159          Pressure                   None        Goal Keeper      False
# 160          Pressure                   None        Goal Keeper       True
# 161          Pressure                   None       Interception      False
# 162          Pressure                   None               Pass      False
# 163          Pressure                   None               Pass       True
# 164            Shield                   None               Pass       True
# 165            Shield                   None               Pass      False
# 166              Shot                   Goal              Block      False
# 167              Shot                   Goal           Pressure      False
# 168              Shot                  Saved        Goal Keeper      False
# 169              Shot       Saved Off Target        Goal Keeper      False
# 170      Substitution                 Injury               Pass       True
# 171      Substitution                 Injury               Pass      False
# 172      Substitution                 Injury  Referee Ball-Drop       True
# 173      Substitution                 Injury  Referee Ball-Drop      False
# 174      Substitution                 Injury               Shot      False
# 175      Substitution                 Injury               Shot       True
# 176      Substitution               Tactical      Ball Recovery      False
# 177      Substitution               Tactical               Pass      False
# 178      Substitution               Tactical               Pass       True
# 179      Substitution               Tactical  Referee Ball-Drop      False
# 180      Substitution               Tactical  Referee Ball-Drop       True
# 181      Substitution               Tactical               Shot      False
# 182      Substitution               Tactical               Shot       True
# 183    Tactical Shift                   None      Ball Recovery      False
# 184    Tactical Shift                   None               Pass      False
# 185    Tactical Shift                   None               Pass       True
# 186    Tactical Shift                   None  Referee Ball-Drop      False
# 187    Tactical Shift                   None  Referee Ball-Drop       True
# 188    Tactical Shift                   None               Shot       True
# 189    Tactical Shift                   None               Shot      False
#
#      count
# 0       44
# 1        1
# 2        3
# 3       19
# 4        4
# 5        1
# 6       19
# 7       28
# 8        2
# 9       29
# 10       2
# 11      62
# 12      71
# 13       1
# 14       1
# 15      11
# 16       3
# 17    2858
# 18     635
# 19    1267
# 20    7791
# 21       7
# 22       1
# 23       1
# 24       1
# 25       3
# 26     679
# 27       4
# 28      70
# 29      27
# 30       2
# 31       1
# 32     268
# 33      18
# 34     542
# 35      88
# 36      49
# 37       5
# 38       1
# 39    2634
# 40     321
# 41       1
# 42       1
# 43       3
# 44       7
# 45       1
# 46    1865
# 47       4
# 48       1
# 49     333
# 50      27
# 51      11
# 52       3
# 53    2152
# 54     198
# 55    1686
# 56       1
# 57      18
# 58      35
# 59     862
# 60      10
# 61      76
# 62       2
# 63      41
# 64       5
# 65       2
# 66    2112
# 67     383
# 68       4
# 69       2
# 70       2
# 71      10
# 72      11
# 73       2
# 74    4036
# 75       2
# 76     218
# 77       7
# 78       1
# 79      81
# 80       7
# 81       1
# 82      10
# 83       1
# 84       3
# 85      36
# 86       6
# 87      15
# 88       1
# 89     498
# 90      21
# 91      64
# 92     179
# 93       1
# 94       2
# 95      64
# 96     304
# 97       6
# 98     155
# 99       2
# 100     13
# 101    505
# 102   1706
# 103     12
# 104     12
# 105     59
# 106     59
# 107      1
# 108    149
# 109     18
# 110    152
# 111    154
# 112     69
# 113     57
# 114      6
# 115      5
# 116     15
# 117      3
# 118     17
# 119      4
# 120   1206
# 121      2
# 122    304
# 123      4
# 124    174
# 125     25
# 126    924
# 127     25
# 128      4
# 129   1694
# 130     10
# 131      1
# 132     75
# 133     10
# 134     16
# 135    768
# 136    149
# 137     32
# 138    527
# 139      1
# 140      5
# 141   1014
# 142      3
# 143      1
# 144      1
# 145      1
# 146    129
# 147     98
# 148     37
# 149     42
# 150      3
# 151      2
# 152      1
# 153     20
# 154     16
# 155      1
# 156      1
# 157    685
# 158     16
# 159     18
# 160      1
# 161      9
# 162   1114
# 163     59
# 164    189
# 165      3
# 166     49
# 167      2
# 168    470
# 169     11
# 170     49
# 171     39
# 172      4
# 173      8
# 174      2
# 175      1
# 176      1
# 177    371
# 178    461
# 179      5
# 180      4
# 181      5
# 182      6
# 183      1
# 184    234
# 185    245
# 186      6
# 187      5
# 188      5
# 189      4

# %% [markdown]
# ## Example Patterns
#
# The following code executes a Cypher statement to find (`MATCH`) Ball Receipts (nodes with a label of `BallReceipt`), then follows the `NEXT_EVENT` relationships from one to three degrees to another ball receipt.  The result is filtered with a `WHERE` clause to make sure all of the nodes in the sequence are performed by the same team as the original ball receipt.
#
# * The `leadsToShot` column is determined by whether the possession leads to a shot (`(:Shot)`) or an own goal (`(:OwnGoalFor)`)
# * The `leadsToGoal` column is true when a goal is scored (the outcome property of the shot is `Goal`) or an own goal is scored (`(:OwnGoalFor)`).
#
# The `RETURN` clause of the Cypher statement calculates the adjusted distance and the duration of the event.

# %%
df = None

with driver.session() as session:
    df = session.run("""
        MATCH sequence = (br1:BallReceipt)-[:NEXT_EVENT*1..3]->(br2:BallReceipt),
            (br1)-[:TEAM]->(t),
            (br1)-[:PLAYER]->(p1),
            (br2)-[:PLAYER]->(p2),
            (br1)-[:MATCH]->(m)-[:AT_STADIUM]->(s),
            (br1)-[:POSSESSION]->(pos)-[:LAST_EVENT]->(last)
        WHERE all(n in nodes(sequence) where (n)-[:TEAM]->(t))
        WITH *, 
            point({ x: br1.location.x * s.ratio.x, y: br1.location.y * s.ratio.y }) AS firstAdjustedLocation,
            point({ x: br2.location.x * s.ratio.x, y: br2.location.y * s.ratio.y }) AS secondAdjustedLocation,
            [ (e)-[:NEXT_EVENT*0..3]->(last) | e.type ] AS lastEvents
        RETURN 
            pos.id AS possession,
            t.name AS team,
            br1.id AS firstReceiptId, 
            p1.id AS passer, 
            p2.id AS receiver, 
            br1.timestamp AS firstReceiptTimestamp,
            [ n in nodes(sequence) | n.type ] AS eventsInSequence, 
            br1.location.x as firstReceiptLocationX,  br1.location.y as firstReceiptLocationY, 
            br2.location.x AS secondReceiptLocationX, br2.location.y AS secondReceiptLocationY,
            point.distance(br1.location, br2.location) AS passDistance, 
            firstAdjustedLocation.x AS firstAdjustedLocationX, firstAdjustedLocation.y AS firstAdjustedLocationY, 
            secondAdjustedLocation.x AS secondAdjustedLocationX, secondAdjustedLocation.y AS secondAdjustedLocationY, 
            point.distance(firstAdjustedLocation, secondAdjustedLocation) AS adjustedPassDistance, 
            time.truncate('day') + duration.between(br1.timestamp, br2.timestamp) AS duration,
            CASE WHEN last:Goalkeeper THEN last.type + ' - '+ last.goalkeeper_type ELSE last.type END AS lastEventType,
            last.outcome AS lastEventOutcome,
            exists { (pos)<-[:POSSESSION]-(:Shot) } or exists { (pos)<-[:POSSESSION]-(:OwnGoalFor) } AS leadsToShot,
            exists { (pos)<-[:POSSESSION]-(:Shot {outcome: "Goal"}) } or exists { (pos)<-[:POSSESSION]-(:OwnGoalFor) } AS leadsToGoal
    """).to_df()
    
    # Save 
    df.to_csv("exports/ball-receipts.csv")

df
# Out:
#           possession            team                        firstReceiptId  \
# 0       3837579--165     Southampton  f5146bf7-1330-46f7-a288-66e3f3c33c3a
# 1       3837579--160     Southampton  e30aa087-6fa6-4cbc-9488-e81dd2c9c3de
# 2       3837579--159     Southampton  64f6215c-5f7c-4449-9cb9-b8a2b46a23fd
# 3       3837579--159     Southampton  dcce8e80-3f4f-4cc4-aa30-39dbb10278f2
# 4       3837579--159     Southampton  09c3b4ca-2a75-40a9-9cc3-839f57dda997
# ...              ...             ...                                   ...
# 251058    3837246--2  Crystal Palace  670b93d8-0210-4757-8830-96f1a55685ed
# 251059    3837246--6       Liverpool  34025752-a1e1-4c51-8977-dee3a525122f
# 251060   3837246--10  Crystal Palace  c999f3cd-4741-471d-8cc2-418f5ffec358
# 251061   3837246--25       Liverpool  cee61525-4a75-4c4c-afd4-b198631d28a9
# 251062   3837246--15       Liverpool  337c4d58-1752-4135-bdf8-05c4c887fbaa
#
#         passer  receiver     firstReceiptTimestamp  \
# 0         3328      3066  00:55:04.308000000+00:00
# 1         4626     49670  00:53:13.427000000+00:00
# 2        22357      4626  00:52:11.901000000+00:00
# 3        22357      3619  00:52:00.236000000+00:00
# 4         4626     24478  00:52:17.118000000+00:00
# ...        ...       ...                       ...
# 251058    8247      9000  00:00:01.560000000+00:00
# 251059   24938      3247  00:03:52.359000000+00:00
# 251060   13851      4590  00:05:28.328000000+00:00
# 251061    3655     27158  00:11:42.455000000+00:00
# 251062   32478      3531  00:06:40.748000000+00:00
#
#                                    eventsInSequence  firstReceiptLocationX  \
# 0       [Ball Receipt*, Carry, Pass, Ball Receipt*]                   47.7
# 1       [Ball Receipt*, Carry, Pass, Ball Receipt*]                   70.9
# 2       [Ball Receipt*, Carry, Pass, Ball Receipt*]                   33.1
# 3       [Ball Receipt*, Carry, Pass, Ball Receipt*]                   20.2
# 4       [Ball Receipt*, Carry, Pass, Ball Receipt*]                   52.1
# ...                                             ...                    ...
# 251058  [Ball Receipt*, Carry, Pass, Ball Receipt*]                   38.1
# 251059  [Ball Receipt*, Carry, Pass, Ball Receipt*]                   70.4
# 251060         [Ball Receipt*, Pass, Ball Receipt*]                   37.8
# 251061  [Ball Receipt*, Carry, Pass, Ball Receipt*]                   43.5
# 251062  [Ball Receipt*, Carry, Pass, Ball Receipt*]                  104.8
#
#         firstReceiptLocationY  secondReceiptLocationX  ...  \
# 0                        28.2                    62.0  ...
# 1                        32.9                    92.0  ...
# 2                        35.4                    52.1  ...
# 3                        23.4                     5.7  ...
# 4                        56.0                   107.7  ...
# ...                       ...                     ...  ...
# 251058                   36.4                    93.9  ...
# 251059                   19.5                    64.3  ...
# 251060                   70.9                    42.5  ...
# 251061                    5.2                    62.2  ...
# 251062                   25.2                   110.4  ...
#
#         firstAdjustedLocationX  firstAdjustedLocationY  \
# 0                    40.545000                  23.970
# 1                    60.265000                  27.965
# 2                    28.135000                  30.090
# 3                    17.170000                  19.890
# 4                    44.285000                  47.600
# ...                        ...                     ...
# 251058               32.067500                  30.940
# 251059               59.253333                  16.575
# 251060               31.815000                  60.265
# 251061               36.612500                   4.420
# 251062               88.206667                  21.420
#
#         secondAdjustedLocationX  secondAdjustedLocationY  \
# 0                     52.700000                   57.885
# 1                     78.200000                    5.780
# 2                     44.285000                   47.600
# 3                      4.845000                   28.900
# 4                     91.545000                   26.350
# ...                         ...                      ...
# 251058                79.032500                    7.820
# 251059                54.119167                   33.745
# 251060                35.770833                   64.685
# 251061                52.351667                    3.995
# 251062                92.920000                   51.425
#
#         adjustedPassDistance                  duration  \
# 0                  36.027368  00:00:03.808000000+00:00
# 1                  28.527854  00:00:03.988000000+00:00
# 2                  23.820634  00:00:05.217000000+00:00
# 3                  15.267145  00:00:02.005000000+00:00
# 4                  51.817662  00:00:04.255000000+00:00
# ...                      ...                       ...
# 251058             52.347355  00:00:04.585000000+00:00
# 251059             17.921177  00:00:02.520000000+00:00
# 251060              5.931696  00:00:01.033000000+00:00
# 251061             15.744904  00:00:01.205000000+00:00
# 251062             30.372941  00:00:07.448000000+00:00
#
#                    lastEventType lastEventOutcome leadsToShot leadsToGoal
# 0       Goal Keeper - Shot Faced             None        True       False
# 1                           Pass       Incomplete       False       False
# 2                  Ball Recovery             None       False       False
# 3                  Ball Recovery             None       False       False
# 4                  Ball Recovery             None       False       False
# ...                          ...              ...         ...         ...
# 251058                     Carry             None       False       False
# 251059                      Pass       Incomplete       False       False
# 251060             Ball Receipt*       Incomplete       False       False
# 251061                      Pass       Incomplete       False       False
# 251062             Ball Receipt*       Incomplete       False       False
#
# [251063 rows x 22 columns]

# %% [markdown]
# ## Next Passes
#
# Save a new `:NEXT_BALL_RECEIPT` relationship based on the data above.

# %%
with driver.session() as session:
    res = session.run("""
        MATCH sequence = (br1:BallReceipt)-[:NEXT_EVENT*1..3]->(br2:BallReceipt),
            (br1)-[:TEAM]->(t),
            (br1)-[:MATCH]->(m)-[:AT_STADIUM]->(s)
        WHERE all(n in nodes(sequence) where (n)-[:TEAM]->(t))
        
        CALL {
            WITH br1, br2, s
            WITH br1, br2, 
                point({ x: br1.location.x * s.ratio.x, y: br1.location.y * s.ratio.y }) AS firstAdjustedLocation,
                point({ x: br2.location.x * s.ratio.x, y: br2.location.y * s.ratio.y }) AS secondAdjustedLocation
            
            MERGE (br1)-[r:NEXT_BALL_RECEIPT]->(br2)
            SET 
                r.distance = point.distance(br1.location, br2.location),
                r.adjustedDistance = point.distance(firstAdjustedLocation, secondAdjustedLocation),
                r.duration = duration.between(br1.timestamp, br2.timestamp)
        } IN TRANSACTIONS OF 1000 ROWS
        
        RETURN count(*) AS count
    """)
    
    print(res.single().get('count'))
# Out:
# 251063

# %% [markdown]
# ## Average duration per Possession
#
# Use the `:NEXT_BALL_RECEIPT` relationships to calculate an average pass duration and provide the final outcome of the possession.

# %%
import pandas as pd
from neo4j import Result

df = driver.execute_query("""
    MATCH (r1:BallReceipt)-[r:NEXT_BALL_RECEIPT]->(r2)-[:POSSESSION]->(p),
        (r1)-[:TEAM]->(t),
        (r1)-[:MATCH]->(m),
        (p)-[:LAST_EVENT]->(last),
        (p)-[:NEXT_POSSESSION]->(npos)-[:FIRST_EVENT]->(nextFirst)
    CALL {
        WITH last
        MATCH p = ()-[:NEXT_EVENT*3]->(last)
        RETURN reduce(output = [], n in nodes(p) | output + [
            n.type 
            + CASE WHEN n.outcome IS NOT NULL THEN ' ('+ n.outcome +')' ELSE '' END 
            + CASE WHEN n.out THEN ' > out' ELSE '' END 
        ]) AS lastEvents
    }
    WITH p, t, m, last, nextFirst, lastEvents,
        count(r) AS events, 
        avg(r.distance) AS avgDistance, 
        avg(r.adjustedDistance) AS avgAdjustedDistance, 
        sum(r.distance) AS totalDistance,
        sum(r.adjustedDistance) AS totalAdjustedDistance, 
        avg(r.duration) AS avgDuration,
        sum(r.duration) AS totalDuration
    RETURN 
        m.name AS name, 
        t.name AS team, 
        p.id AS possession, 
        events,
        time.truncate('day') + avgDuration AS avgDuration, 
        time.truncate('day') + totalDuration AS totalDuration, 
        avgDistance, 
        totalDistance,
        avgAdjustedDistance, 
        totalAdjustedDistance,
        round(avgAdjustedDistance / avgDuration.milliseconds * 1000, 2) AS tempo,
        last.type AS lastType, 
        last.outcome AS lastOutcome,
        lastEvents,
        exists { (p)<-[:POSSESSION]-(:Shot) } or exists { (p)<-[:POSSESSION]-(:OwnGoalFor) } AS leadsToShot,
        exists { (p)<-[:POSSESSION]-(:Shot {outcome: "Goal"}) } or exists { (p)<-[:POSSESSION]-(:OwnGoalFor) } AS leadsToGoal,
        CASE 
          WHEN (p)<-[:POSSESSION]-(:Shot) OR (nextFirst)-[:TEAM]->(t) THEN 'Positive'
          WHEN any(type in lastEvents WHERE type in ['Foul Won']) AND (last)-[:TEAM]->(t) THEN 'Positive'
          WHEN last.outcome = "Incomplete" THEN 'Negative'
          WHEN any(type in lastEvents WHERE type in ['Dispossessed', 'Miscontrol', 'Interception', 'Clearance', 'Error', 'Pressure']) THEN 'Negative'
          WHEN NOT (nextFirst)-[:TEAM]->(t) THEN 'Negative'
        END AS outcome
""", result_transformer_=Result.to_df)

df.to_csv('exports/possessions.csv')

df
# Out:
#                                               name               team  \
# 0       2023-05-08 Nottingham Forest v Southampton  Nottingham Forest
# 1       2023-05-08 Nottingham Forest v Southampton  Nottingham Forest
# 2       2023-05-08 Nottingham Forest v Southampton        Southampton
# 3       2023-05-08 Nottingham Forest v Southampton  Nottingham Forest
# 4           2023-05-25 Manchester United v Chelsea  Manchester United
# ...                                            ...                ...
# 45452  2023-05-28 Leicester City v West Ham United     Leicester City
# 45453  2023-05-28 Leicester City v West Ham United     Leicester City
# 45454  2023-05-28 Leicester City v West Ham United     Leicester City
# 45455  2023-05-28 Leicester City v West Ham United    West Ham United
# 45456  2023-05-28 Leicester City v West Ham United     Leicester City
#
#          possession  events               avgDuration  \
# 0       3837579--32       2  00:00:02.791000000+00:00
# 1       3837579--36      12  00:00:02.466583333+00:00
# 2       3837579--40       2  00:00:03.311500000+00:00
# 3      3837579--124       6  00:00:02.163500000+00:00
# 4       3837548--75       3  00:00:01.781000000+00:00
# ...             ...     ...                       ...
# 45452  3837604--160       5  00:00:02.940400000+00:00
# 45453  3837604--162       1  00:00:00.496000000+00:00
# 45454  3837604--163       2  00:00:00.830500000+00:00
# 45455  3837604--167       6  00:00:02.606499999+00:00
# 45456  3837604--168       3  00:00:02.345000000+00:00
#
#                   totalDuration  avgDistance  totalDistance  \
# 0      00:00:05.582000000+00:00    46.994486      93.988972
# 1      00:00:29.599000000+00:00    15.902714     190.832567
# 2      00:00:06.623000000+00:00    31.038661      62.077322
# 3      00:00:12.981000000+00:00    19.128571     114.771426
# 4      00:00:05.343000000+00:00    12.749972      38.249917
# ...                         ...          ...            ...
# 45452  00:00:14.702000000+00:00    30.654161     153.270807
# 45453  00:00:00.496000000+00:00    14.328294      14.328294
# 45454  00:00:01.661000000+00:00     6.590527      13.181054
# 45455  00:00:15.639000000+00:00    22.396236     134.377414
# 45456  00:00:07.035000000+00:00    16.565447      49.696342
#
#        avgAdjustedDistance  totalAdjustedDistance  tempo       lastType  \
# 0                39.945313              79.890626  14.31    Goal Keeper
# 1                13.517307             162.207682   5.48    Goal Keeper
# 2                26.382862              52.765724   7.97    Goal Keeper
# 3                16.259285              97.555712   7.52    Goal Keeper
# 4                10.921876              32.765629   6.13    Goal Keeper
# ...                    ...                    ...    ...            ...
# 45452            26.554881             132.774405   9.03     Player Off
# 45453            12.535864              12.535864  25.27          Block
# 45454             5.720006              11.440012   6.89          Block
# 45455            19.321011             115.926063   7.41   Dispossessed
# 45456            14.428666              43.285999   6.15  Ball Receipt*
#
#       lastOutcome                                         lastEvents  \
# 0      Touched In  [Pass, Ball Receipt*, Shot (Goal), Goal Keeper...
# 1        No Touch  [Pass, Ball Receipt*, Shot (Goal), Goal Keeper...
# 2        No Touch  [Ball Receipt*, Carry, Shot (Goal), Goal Keepe...
# 3        No Touch  [Pass, Ball Receipt*, Shot (Goal), Goal Keeper...
# 4        No Touch  [Pass, Ball Receipt*, Shot (Goal), Goal Keeper...
# ...           ...                                                ...
# 45452        None  [Ball Receipt*, Injury Stoppage, Injury Stoppa...
# 45453        None  [Carry, Pass (Incomplete), Ball Receipt* (Inco...
# 45454        None  [Carry, Pass (Incomplete), Ball Receipt* (Inco...
# 45455        None         [Pass, Ball Receipt*, Carry, Dispossessed]
# 45456  Incomplete  [Pass (Incomplete), Ball Receipt* (Incomplete)...
#
#        leadsToShot  leadsToGoal   outcome
# 0             True         True  Positive
# 1             True         True  Positive
# 2             True         True  Positive
# 3             True         True  Positive
# 4             True         True  Positive
# ...            ...          ...       ...
# 45452        False        False  Negative
# 45453        False        False  Positive
# 45454        False        False  Positive
# 45455        False        False  Negative
# 45456        False        False  Negative
#
# [45457 rows x 17 columns]

# %% [markdown]
# The `outcome` is **positive** when:
# * The possession contains a shot (on target or off target)
# * The team from the first possession also perform the first event of the next possession
# * A foul is won by the possession team
#
# The `outcome` is **negative** when:
# * The last event is an incomplete pass
# * One of the following types are in the last four events (`0..3`) of the sequence:
#   * 'Dispossessed', 'Miscontrol', 'Interception', 'Clearance', 'Error', 'Pressure']
# * The first event in the next possessions is performed by the opposition
